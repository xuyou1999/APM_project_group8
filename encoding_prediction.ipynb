# %%
import pm4py
import pandas as pd
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
import numpy as np
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Data pre-processing

# %% [markdown]
# Event logs are already filtered and projected in ProM.
# - A_events_new.xes contains only A events with traces ending with A_Pending, A_Cancelled, A_Denied. This log is used for label extraction.
# - OA_events.xes contains A and O events. This log is used for prefix and feature extraction.
#
# After processing, both logs are joined together to form the final set.

# %%
# Open the event logs
event_log1 = pm4py.read_xes('data/A_events_new.xes')
event_log2 = pm4py.read_xes('data/OA_events.xes')
# Out:
# /Users/xuyou/opt/anaconda3/lib/python3.9/site-packages/pm4py/util/dt_parsing/parser.py:77: UserWarning: ISO8601 strings are not fully supported with strpfromiso for Python versions below 3.11
#   warnings.warn(
# parsing log, completed traces ::   0%|          | 0/31411 [00:00<?, ?it/s]
# parsing log, completed traces ::   0%|          | 0/31509 [00:00<?, ?it/s]

# %%
# Convert the event logs to dataframes
df1 = pm4py.convert_to_dataframe(event_log1)
df2 = pm4py.convert_to_dataframe(event_log2)

# %%
# Nomalize the timestamps
df1['time:timestamp'] = pd.to_datetime(df1['time:timestamp'], utc=True)
df2['time:timestamp'] = pd.to_datetime(df2['time:timestamp'], utc=True)
df1['Year'] = df1['time:timestamp'].dt.year
df1['Month'] = df1['time:timestamp'].dt.month

# %% [markdown]
# # Add label

# %% [markdown]
# Based on the end activies
# - If the trace ends with A_Pending "successful"
# - If the trace ends with A_Cancelled or A_Denied, the label is "unsuccessful"

# %%
success_log = pm4py.filter_end_activities(event_log1, ["A_Pending"])
unsuccess_log = pm4py.filter_end_activities(event_log1, ["A_Cancelled", "A_Denied"])
df_suc = pm4py.convert_to_dataframe(success_log)
df_unsuc = pm4py.convert_to_dataframe(unsuccess_log)

df_suc['label'] = 'successful'
df_unsuc['label'] = 'unsuccessful'

# Concatenate the DataFrames
df1 = pd.concat([df_suc, df_unsuc], ignore_index=True)
df1.head()
# Out:
# /var/folders/v1/m2nqhx3d4yv9mjbpndrlsck00000gn/T/ipykernel_30669/2030576452.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_suc['label'] = 'successful'
# /var/folders/v1/m2nqhx3d4yv9mjbpndrlsck00000gn/T/ipykernel_30669/2030576452.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unsuc['label'] = 'unsuccessful'
#         Action                EventID  EventOrigin org:resource  \
# 0      Created  Application_652823628  Application       User_1
# 1  statechange   ApplState_1582051990  Application       User_1
# 2  statechange    ApplState_642383566  Application       User_1
# 3  statechange     ApplState_99568828  Application      User_52
# 4  statechange    ApplState_946455804  Application      User_52
#
#            concept:name lifecycle:transition                   time:timestamp  \
# 0  A_Create Application             complete 2016-01-01 09:51:15.304000+00:00
# 1           A_Submitted             complete 2016-01-01 09:51:15.352000+00:00
# 2             A_Concept             complete 2016-01-01 09:52:36.413000+00:00
# 3            A_Accepted             complete 2016-01-02 11:23:04.299000+00:00
# 4            A_Complete             complete 2016-01-02 11:30:28.633000+00:00
#
#             case:LoanGoal case:ApplicationType  case:RequestedAmount  \
# 0  Existing loan takeover           New credit               20000.0
# 1  Existing loan takeover           New credit               20000.0
# 2  Existing loan takeover           New credit               20000.0
# 3  Existing loan takeover           New credit               20000.0
# 4  Existing loan takeover           New credit               20000.0
#
#        case:concept:name  Year  Month       label
# 0  Application_652823628  2016      1  successful
# 1  Application_652823628  2016      1  successful
# 2  Application_652823628  2016      1  successful
# 3  Application_652823628  2016      1  successful
# 4  Application_652823628  2016      1  successful

# %% [markdown]
# # Prefix Encoding
# We aim to predict the outcome of the application when the offer is sent. Therefore, all events before offer sent (included) are encoded as prefix.

# %%
# Show all unique events
unique_events = sorted(df2['concept:name'].unique())
unique_events
# Out:
# ['A_Accepted',
#  'A_Cancelled',
#  'A_Complete',
#  'A_Concept',
#  'A_Create Application',
#  'A_Denied',
#  'A_Incomplete',
#  'A_Pending',
#  'A_Submitted',
#  'A_Validating',
#  'O_Accepted',
#  'O_Cancelled',
#  'O_Create Offer',
#  'O_Created',
#  'O_Refused',
#  'O_Returned',
#  'O_Sent (mail and online)',
#  'O_Sent (online only)']

# %% [markdown]
# ### Filter the event log to extract prefix

# %%
# Filter the events so that only the events before O_Sent (mail and online) or O_Sent (online only) of each trace are kept
df2 = df2.sort_values(by=['case:concept:name', 'time:timestamp'])

# Function to filter rows
def filter_rows(group):
    # Find the first occurrence of the specified 'concept:name'
    idx = group[group['concept:name'].isin(['O_Sent (mail and online)', 'O_Sent (online only)'])].index.min()
    # If found, keep rows up to and including the first occurrence
    if pd.notna(idx):
        return group.loc[:idx]
    # If not found, return the group as is
    return group

# Apply the function to each group and combine the results
filtered_df2 = df2.groupby('case:concept:name', group_keys=False).apply(filter_rows)

# %% [markdown]
# ### Encode the prefix by Aggreagation

# %%
result = pd.crosstab(filtered_df2['case:concept:name'], filtered_df2['concept:name']).reindex(unique_events, axis=1, fill_value=0)
result.head()
# Out:
# concept:name            A_Accepted  A_Cancelled  A_Complete  A_Concept  \
# case:concept:name
# Application_1000086665           1            0           0          1
# Application_1000158214           1            0           0          1
# Application_1000311556           1            0           0          1
# Application_1000334415           1            0           0          1
# Application_1000339879           1            0           0          1
#
# concept:name            A_Create Application  A_Denied  A_Incomplete  \
# case:concept:name
# Application_1000086665                     1         0             0
# Application_1000158214                     1         0             0
# Application_1000311556                     1         0             0
# Application_1000334415                     1         0             0
# Application_1000339879                     1         0             0
#
# concept:name            A_Pending  A_Submitted  A_Validating  O_Accepted  \
# case:concept:name
# Application_1000086665          0            1             0           0
# Application_1000158214          0            1             0           0
# Application_1000311556          0            0             0           0
# Application_1000334415          0            1             0           0
# Application_1000339879          0            1             0           0
#
# concept:name            O_Cancelled  O_Create Offer  O_Created  O_Refused  \
# case:concept:name
# Application_1000086665            0               1          1          0
# Application_1000158214            0               1          1          0
# Application_1000311556            0               1          1          0
# Application_1000334415            0               1          1          0
# Application_1000339879            0               1          1          0
#
# concept:name            O_Returned  O_Sent (mail and online)  \
# case:concept:name
# Application_1000086665           0                         1
# Application_1000158214           0                         1
# Application_1000311556           0                         1
# Application_1000334415           0                         1
# Application_1000339879           0                         1
#
# concept:name            O_Sent (online only)
# case:concept:name
# Application_1000086665                     0
# Application_1000158214                     0
# Application_1000311556                     0
# Application_1000334415                     0
# Application_1000339879                     0

# %% [markdown]
# # Getting trace attribute and merge

# %%
# Extract the case attributes
case_attr_df1 = df1.groupby('case:concept:name').agg({
    'case:LoanGoal': 'first',
    'case:RequestedAmount': 'first',
    'case:ApplicationType': 'first',
    'time:timestamp': 'first',
    'Month': 'first',
    'Year': 'first',
    'label': 'first'
}).reset_index()
case_attr_df1.head()
# Out:
#         case:concept:name           case:LoanGoal  case:RequestedAmount  \
# 0  Application_1000086665  Other, see explanation                5000.0
# 1  Application_1000158214        Home improvement               12500.0
# 2  Application_1000311556                     Car               45000.0
# 3  Application_1000334415  Other, see explanation                5000.0
# 4  Application_1000339879  Existing loan takeover               37500.0
#
#   case:ApplicationType                   time:timestamp  Month  Year  \
# 0           New credit 2016-08-03 15:57:21.673000+00:00      8  2016
# 1           New credit 2016-06-02 10:14:26.844000+00:00      6  2016
# 2           New credit 2016-04-04 15:56:37.675000+00:00      4  2016
# 3           New credit 2016-09-15 16:39:17.758000+00:00      9  2016
# 4           New credit 2016-03-17 12:57:10.159000+00:00      3  2016
#
#           label
# 0  unsuccessful
# 1    successful
# 2  unsuccessful
# 3  unsuccessful
# 4    successful

# %%
# Merge the trace attributes with the prefix encoding
merged_df = pd.merge(result, case_attr_df1, on='case:concept:name', how='inner')
merged_df = merged_df.set_index('case:concept:name')
merged_df.head()
# Out:
#                         A_Accepted  A_Cancelled  A_Complete  A_Concept  \
# case:concept:name
# Application_1000086665           1            0           0          1
# Application_1000158214           1            0           0          1
# Application_1000311556           1            0           0          1
# Application_1000334415           1            0           0          1
# Application_1000339879           1            0           0          1
#
#                         A_Create Application  A_Denied  A_Incomplete  \
# case:concept:name
# Application_1000086665                     1         0             0
# Application_1000158214                     1         0             0
# Application_1000311556                     1         0             0
# Application_1000334415                     1         0             0
# Application_1000339879                     1         0             0
#
#                         A_Pending  A_Submitted  A_Validating  ...  O_Returned  \
# case:concept:name                                             ...
# Application_1000086665          0            1             0  ...           0
# Application_1000158214          0            1             0  ...           0
# Application_1000311556          0            0             0  ...           0
# Application_1000334415          0            1             0  ...           0
# Application_1000339879          0            1             0  ...           0
#
#                         O_Sent (mail and online)  O_Sent (online only)  \
# case:concept:name
# Application_1000086665                         1                     0
# Application_1000158214                         1                     0
# Application_1000311556                         1                     0
# Application_1000334415                         1                     0
# Application_1000339879                         1                     0
#
#                                  case:LoanGoal  case:RequestedAmount  \
# case:concept:name
# Application_1000086665  Other, see explanation                5000.0
# Application_1000158214        Home improvement               12500.0
# Application_1000311556                     Car               45000.0
# Application_1000334415  Other, see explanation                5000.0
# Application_1000339879  Existing loan takeover               37500.0
#
#                         case:ApplicationType                   time:timestamp  \
# case:concept:name
# Application_1000086665            New credit 2016-08-03 15:57:21.673000+00:00
# Application_1000158214            New credit 2016-06-02 10:14:26.844000+00:00
# Application_1000311556            New credit 2016-04-04 15:56:37.675000+00:00
# Application_1000334415            New credit 2016-09-15 16:39:17.758000+00:00
# Application_1000339879            New credit 2016-03-17 12:57:10.159000+00:00
#
#                         Month  Year         label
# case:concept:name
# Application_1000086665      8  2016  unsuccessful
# Application_1000158214      6  2016    successful
# Application_1000311556      4  2016  unsuccessful
# Application_1000334415      9  2016  unsuccessful
# Application_1000339879      3  2016    successful
#
# [5 rows x 25 columns]

# %% [markdown]
# # Encode categorical features using one-hot encoding

# %%
one_hot_encoded_data = pd.get_dummies(merged_df['case:LoanGoal'], prefix='LoanGoal')
merged_df = merged_df.join(one_hot_encoded_data)
merged_df = merged_df.drop(columns=['case:LoanGoal'])

one_hot_encoded_data = pd.get_dummies(merged_df['case:ApplicationType'], prefix='ApplicationType')
merged_df = merged_df.join(one_hot_encoded_data)
merged_df = merged_df.drop(columns=['case:ApplicationType'])

merged_df.head()
# Out:
#                         A_Accepted  A_Cancelled  A_Complete  A_Concept  \
# case:concept:name
# Application_1000086665           1            0           0          1
# Application_1000158214           1            0           0          1
# Application_1000311556           1            0           0          1
# Application_1000334415           1            0           0          1
# Application_1000339879           1            0           0          1
#
#                         A_Create Application  A_Denied  A_Incomplete  \
# case:concept:name
# Application_1000086665                     1         0             0
# Application_1000158214                     1         0             0
# Application_1000311556                     1         0             0
# Application_1000334415                     1         0             0
# Application_1000339879                     1         0             0
#
#                         A_Pending  A_Submitted  A_Validating  ...  \
# case:concept:name                                             ...
# Application_1000086665          0            1             0  ...
# Application_1000158214          0            1             0  ...
# Application_1000311556          0            0             0  ...
# Application_1000334415          0            1             0  ...
# Application_1000339879          0            1             0  ...
#
#                         LoanGoal_Extra spending limit  \
# case:concept:name
# Application_1000086665                              0
# Application_1000158214                              0
# Application_1000311556                              0
# Application_1000334415                              0
# Application_1000339879                              0
#
#                         LoanGoal_Home improvement  LoanGoal_Motorcycle  \
# case:concept:name
# Application_1000086665                          0                    0
# Application_1000158214                          1                    0
# Application_1000311556                          0                    0
# Application_1000334415                          0                    0
# Application_1000339879                          0                    0
#
#                         LoanGoal_Not speficied  \
# case:concept:name
# Application_1000086665                       0
# Application_1000158214                       0
# Application_1000311556                       0
# Application_1000334415                       0
# Application_1000339879                       0
#
#                         LoanGoal_Other, see explanation  \
# case:concept:name
# Application_1000086665                                1
# Application_1000158214                                0
# Application_1000311556                                0
# Application_1000334415                                1
# Application_1000339879                                0
#
#                         LoanGoal_Remaining debt home  LoanGoal_Tax payments  \
# case:concept:name
# Application_1000086665                             0                      0
# Application_1000158214                             0                      0
# Application_1000311556                             0                      0
# Application_1000334415                             0                      0
# Application_1000339879                             0                      0
#
#                         LoanGoal_Unknown  ApplicationType_Limit raise  \
# case:concept:name
# Application_1000086665                 0                            0
# Application_1000158214                 0                            0
# Application_1000311556                 0                            0
# Application_1000334415                 0                            0
# Application_1000339879                 0                            0
#
#                        ApplicationType_New credit
# case:concept:name
# Application_1000086665                          1
# Application_1000158214                          1
# Application_1000311556                          1
# Application_1000334415                          1
# Application_1000339879                          1
#
# [5 rows x 39 columns]

# %% [markdown]
# # Train test split

# %%
merged_df['time:timestamp'] = pd.to_datetime(merged_df['time:timestamp'])
merged_df.sort_values(by=['time:timestamp'], inplace=True)
merged_df.head()
# Out:
#                         A_Accepted  A_Cancelled  A_Complete  A_Concept  \
# case:concept:name
# Application_652823628            1            0           0          1
# Application_1691306052           1            0           0          1
# Application_428409768            1            0           0          1
# Application_1746793196           1            0           0          1
# Application_828200680            1            0           0          1
#
#                         A_Create Application  A_Denied  A_Incomplete  \
# case:concept:name
# Application_652823628                      1         0             0
# Application_1691306052                     1         0             0
# Application_428409768                      1         0             0
# Application_1746793196                     1         0             0
# Application_828200680                      1         0             0
#
#                         A_Pending  A_Submitted  A_Validating  ...  \
# case:concept:name                                             ...
# Application_652823628           0            1             0  ...
# Application_1691306052          0            1             0  ...
# Application_428409768           0            1             0  ...
# Application_1746793196          0            1             0  ...
# Application_828200680           0            1             0  ...
#
#                         LoanGoal_Extra spending limit  \
# case:concept:name
# Application_652823628                               0
# Application_1691306052                              0
# Application_428409768                               0
# Application_1746793196                              0
# Application_828200680                               0
#
#                         LoanGoal_Home improvement  LoanGoal_Motorcycle  \
# case:concept:name
# Application_652823628                           0                    0
# Application_1691306052                          1                    0
# Application_428409768                           1                    0
# Application_1746793196                          0                    0
# Application_828200680                           1                    0
#
#                         LoanGoal_Not speficied  \
# case:concept:name
# Application_652823628                        0
# Application_1691306052                       0
# Application_428409768                        0
# Application_1746793196                       0
# Application_828200680                        0
#
#                         LoanGoal_Other, see explanation  \
# case:concept:name
# Application_652823628                                 0
# Application_1691306052                                0
# Application_428409768                                 0
# Application_1746793196                                0
# Application_828200680                                 0
#
#                         LoanGoal_Remaining debt home  LoanGoal_Tax payments  \
# case:concept:name
# Application_652823628                              0                      0
# Application_1691306052                             0                      0
# Application_428409768                              0                      0
# Application_1746793196                             0                      0
# Application_828200680                              0                      0
#
#                         LoanGoal_Unknown  ApplicationType_Limit raise  \
# case:concept:name
# Application_652823628                  0                            0
# Application_1691306052                 0                            0
# Application_428409768                  0                            0
# Application_1746793196                 0                            0
# Application_828200680                  0                            0
#
#                        ApplicationType_New credit
# case:concept:name
# Application_652823628                           1
# Application_1691306052                          1
# Application_428409768                           1
# Application_1746793196                          1
# Application_828200680                           1
#
# [5 rows x 39 columns]

# %% [markdown]
# ### Split the data into train and test set. Following time order, the first 70% of the traces are used for training, the next 10% for vallidation, and the last 20% for testing.

# %%
total_rows = len(merged_df)
train_size = int(0.7 * total_rows)
validation_size = int(0.1 * total_rows)
test_size = total_rows - train_size - validation_size

train = merged_df[:train_size]
validation = merged_df[train_size:train_size + validation_size]
test = merged_df[train_size + validation_size:]

# %%
# Splitting the training set
X_train = train.drop('label', axis=1)
X_train = X_train.drop('time:timestamp', axis=1)
X_train = X_train.drop('Month', axis=1)
X_train = X_train.drop('Year', axis=1)
y_train = train['label']

# Splitting the validation set
X_validation = validation.drop('label', axis=1)
X_validation = X_validation.drop('time:timestamp', axis=1)
X_validation = X_validation.drop('Month', axis=1)
X_validation = X_validation.drop('Year', axis=1)
y_validation = validation['label']

# Splitting the testing set
X_test = test.drop('label', axis=1)
X_test = X_test.drop('time:timestamp', axis=1)
X_test = X_test.drop('Month', axis=1)
X_test = X_test.drop('Year', axis=1)
y_test = test['label']

# %%
X_train.head()
# Out:
#                         A_Accepted  A_Cancelled  A_Complete  A_Concept  \
# case:concept:name
# Application_652823628            1            0           0          1
# Application_1691306052           1            0           0          1
# Application_428409768            1            0           0          1
# Application_1746793196           1            0           0          1
# Application_828200680            1            0           0          1
#
#                         A_Create Application  A_Denied  A_Incomplete  \
# case:concept:name
# Application_652823628                      1         0             0
# Application_1691306052                     1         0             0
# Application_428409768                      1         0             0
# Application_1746793196                     1         0             0
# Application_828200680                      1         0             0
#
#                         A_Pending  A_Submitted  A_Validating  ...  \
# case:concept:name                                             ...
# Application_652823628           0            1             0  ...
# Application_1691306052          0            1             0  ...
# Application_428409768           0            1             0  ...
# Application_1746793196          0            1             0  ...
# Application_828200680           0            1             0  ...
#
#                         LoanGoal_Extra spending limit  \
# case:concept:name
# Application_652823628                               0
# Application_1691306052                              0
# Application_428409768                               0
# Application_1746793196                              0
# Application_828200680                               0
#
#                         LoanGoal_Home improvement  LoanGoal_Motorcycle  \
# case:concept:name
# Application_652823628                           0                    0
# Application_1691306052                          1                    0
# Application_428409768                           1                    0
# Application_1746793196                          0                    0
# Application_828200680                           1                    0
#
#                         LoanGoal_Not speficied  \
# case:concept:name
# Application_652823628                        0
# Application_1691306052                       0
# Application_428409768                        0
# Application_1746793196                       0
# Application_828200680                        0
#
#                         LoanGoal_Other, see explanation  \
# case:concept:name
# Application_652823628                                 0
# Application_1691306052                                0
# Application_428409768                                 0
# Application_1746793196                                0
# Application_828200680                                 0
#
#                         LoanGoal_Remaining debt home  LoanGoal_Tax payments  \
# case:concept:name
# Application_652823628                              0                      0
# Application_1691306052                             0                      0
# Application_428409768                              0                      0
# Application_1746793196                             0                      0
# Application_828200680                              0                      0
#
#                         LoanGoal_Unknown  ApplicationType_Limit raise  \
# case:concept:name
# Application_652823628                  0                            0
# Application_1691306052                 0                            0
# Application_428409768                  0                            0
# Application_1746793196                 0                            0
# Application_828200680                  0                            0
#
#                         ApplicationType_New credit
# case:concept:name
# Application_652823628                            1
# Application_1691306052                           1
# Application_428409768                            1
# Application_1746793196                           1
# Application_828200680                            1
#
# [5 rows x 35 columns]

# %%
y_train.head()
# Out:
# case:concept:name
# Application_652823628       successful
# Application_1691306052    unsuccessful
# Application_428409768       successful
# Application_1746793196      successful
# Application_828200680     unsuccessful
# Name: label, dtype: object

# %%
y_test.head()
# Out:
# case:concept:name
# Application_1046222107      successful
# Application_1235896381    unsuccessful
# Application_1985757094    unsuccessful
# Application_396092392     unsuccessful
# Application_585529210       successful
# Name: label, dtype: object

# %% [markdown]
# # Create naive predictors
# For the test set, randomly assign the two lables.

# %%
np.random.seed(0)

# Randomly assign 'successful' or 'unsuccessful'
statuses = ['successful', 'unsuccessful']
y_test_naive = pd.Series(np.random.choice(statuses, size=len(y_test)), index=y_test.index)

# Display the new DataFrame
print(y_test_naive[:10])
# Out:
# case:concept:name
# Application_1046222107      successful
# Application_1235896381    unsuccessful
# Application_1985757094    unsuccessful
# Application_396092392       successful
# Application_585529210     unsuccessful
# Application_1751900898    unsuccessful
# Application_867435788     unsuccessful
# Application_543098684     unsuccessful
# Application_1090974006    unsuccessful
# Application_2087713022    unsuccessful
# dtype: object

# %% [markdown]
# # Prediction

# %% [markdown]
# ## Naive Predictor Performance

# %%
accuracy_score(y_test_naive, y_test)
# Out:
# 0.5091516791341716

# %% [markdown]
# ## Decision Tree

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

# %%
accuracy = clf.score(X_test, y_test)
accuracy
# Out:
# 0.5779086423682954

# %% [markdown]
# ## SVM

# %%
clf = svm.SVC()
clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
accuracy = clf.score(X_test, y_test)
accuracy
# Out:
# 0.5505331847843387

# %% [markdown]
# ## Gradient Boosting

# %%
clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
    max_depth=1, random_state=0).fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.593187967531434

# %% [markdown]
# ## Logistic Regression

# %%
clf = LogisticRegression(random_state=0).fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.5489415884131784

# %% [markdown]
# ## Newral Network (MLP)

# %%
clf = MLPClassifier(solver='lbfgs', alpha=1e-5,
                    hidden_layer_sizes=(5, 2), random_state=1)
clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.5489415884131784
