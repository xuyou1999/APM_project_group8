# %% [markdown]
# ## Import required libraries

# %%
import pm4py
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import Log

# %% [markdown]
# There are two logs to explore. Both are filtered and projected using ProM. They include information about events, loan goal, application type and requested amount.
# - event_log_full is the full log that represents the process with A_ and O_ completed events
# - event_log_A contains only A_ events with traces ending with A_Pending, A_Cancelled, A_Denied. This log is used to analyse the application process outcome (successful/unsuccessful applications)
#
# **<span style="color:red">Following paths for `event_log_full` and `event_log_A` must be changed before running</span>**

# %%
event_log_full = pm4py.read_xes('/../OA_events.xes')
event_log_A = pm4py.read_xes('/../end_A_event_log.xes')
# Out:
# parsing log, completed traces ::   0%|                | 0/31509 [00:00<?, ?it/s]
# parsing log, completed traces ::   0%|      | 1/31509 [00:00<4:20:35,  2.02it/s]
# parsing log, completed traces ::   1%|     | 160/31509 [00:00<01:27, 356.56it/s]
# parsing log, completed traces ::   1%|     | 323/31509 [00:00<00:46, 664.46it/s]
# parsing log, completed traces ::   2%|     | 482/31509 [00:00<00:34, 901.51it/s]
# parsing log, completed traces ::   2%|    | 642/31509 [00:00<00:28, 1086.28it/s]
# parsing log, completed traces ::   3%|    | 812/31509 [00:00<00:24, 1255.65it/s]
# parsing log, completed traces ::   3%|    | 966/31509 [00:01<00:22, 1336.10it/s]
# parsing log, completed traces ::   4%|   | 1128/31509 [00:01<00:21, 1414.77it/s]
# parsing log, completed traces ::   4%|   | 1299/31509 [00:01<00:20, 1498.05it/s]
# parsing log, completed traces ::   5%|▏  | 1460/31509 [00:01<00:19, 1506.49it/s]
# parsing log, completed traces ::   5%|▏  | 1624/31509 [00:01<00:19, 1542.10it/s]
# parsing log, completed traces ::   6%|▏  | 1784/31509 [00:01<00:19, 1538.66it/s]
# parsing log, completed traces ::   6%|▏  | 1942/31509 [00:01<00:19, 1508.51it/s]
# parsing log, completed traces ::   7%|▏  | 2113/31509 [00:01<00:18, 1565.63it/s]
# parsing log, completed traces ::   7%|▏  | 2296/31509 [00:01<00:17, 1640.93it/s]
# parsing log, completed traces ::   8%|▏  | 2472/31509 [00:02<00:17, 1675.85it/s]
# parsing log, completed traces ::   8%|▎  | 2658/31509 [00:02<00:16, 1728.89it/s]
# parsing log, completed traces ::  18%|▌  | 5595/31509 [38:06<2:56:29,  2.45it/s]
#
# parsing log, completed traces ::  10%|▍   | 3021/31509 [00:03<01:32, 307.65it/s]
# parsing log, completed traces ::  10%|▍   | 3196/31509 [00:04<01:09, 406.48it/s]
# parsing log, completed traces ::  11%|▍   | 3371/31509 [00:04<00:53, 526.15it/s]
# parsing log, completed traces ::  11%|▍   | 3556/31509 [00:04<00:41, 674.86it/s]
# parsing log, completed traces ::  12%|▍   | 3738/31509 [00:04<00:33, 833.68it/s]
# parsing log, completed traces ::  12%|▍   | 3907/31509 [00:04<00:28, 974.86it/s]
# parsing log, completed traces ::  13%|▍  | 4090/31509 [00:04<00:24, 1137.33it/s]
# parsing log, completed traces ::  14%|▍  | 4270/31509 [00:04<00:21, 1278.57it/s]
# parsing log, completed traces ::  14%|▍  | 4448/31509 [00:04<00:19, 1395.33it/s]
# parsing log, completed traces ::  15%|▍  | 4630/31509 [00:04<00:17, 1501.52it/s]
# parsing log, completed traces ::  15%|▍  | 4813/31509 [00:04<00:16, 1586.30it/s]
# parsing log, completed traces ::  16%|▍  | 4992/31509 [00:05<00:16, 1638.75it/s]
# parsing log, completed traces ::  16%|▍  | 5176/31509 [00:05<00:15, 1694.57it/s]
# parsing log, completed traces ::  17%|▌  | 5356/31509 [00:05<00:15, 1724.06it/s]
# parsing log, completed traces ::  18%|▌  | 5538/31509 [00:05<00:14, 1750.14it/s]
# parsing log, completed traces ::  18%|▌  | 5725/31509 [00:05<00:14, 1784.89it/s]
# parsing log, completed traces ::  19%|▌  | 5909/31509 [00:05<00:14, 1799.96it/s]
# parsing log, completed traces ::  19%|▌  | 6092/31509 [00:05<00:14, 1801.60it/s]
# parsing log, completed traces ::  20%|▌  | 6275/31509 [00:05<00:13, 1809.51it/s]
# parsing log, completed traces ::  20%|▌  | 6458/31509 [00:05<00:13, 1789.45it/s]
# parsing log, completed traces ::  21%|▋  | 6638/31509 [00:05<00:14, 1752.96it/s]
# parsing log, completed traces ::  22%|▋  | 6815/31509 [00:06<00:14, 1744.98it/s]
# parsing log, completed traces ::  22%|▋  | 6994/31509 [00:06<00:13, 1755.47it/s]
# parsing log, completed traces ::  23%|▋  | 7175/31509 [00:06<00:13, 1771.17it/s]
# parsing log, completed traces ::  23%|▋  | 7353/31509 [00:06<00:13, 1750.09it/s]
# parsing log, completed traces ::  24%|▋  | 7538/31509 [00:06<00:13, 1776.18it/s]
# parsing log, completed traces ::  24%|▋  | 7716/31509 [00:06<00:13, 1728.51it/s]
# parsing log, completed traces ::  25%|▊  | 7890/31509 [00:06<00:13, 1718.80it/s]
# parsing log, completed traces ::  26%|▊  | 8076/31509 [00:06<00:13, 1753.44it/s]
# parsing log, completed traces ::  26%|▊  | 8252/31509 [00:06<00:13, 1733.66it/s]
# parsing log, completed traces ::  27%|▊  | 8429/31509 [00:06<00:13, 1743.60it/s]
# parsing log, completed traces ::  27%|▊  | 8604/31509 [00:07<00:13, 1729.31it/s]
# parsing log, completed traces ::  28%|▊  | 8781/31509 [00:07<00:13, 1739.61it/s]
# parsing log, completed traces ::  28%|▊  | 8956/31509 [00:07<00:13, 1733.46it/s]
# parsing log, completed traces ::  29%|▊  | 9130/31509 [00:07<00:12, 1731.42it/s]
# parsing log, completed traces ::  30%|▉  | 9304/31509 [00:07<00:12, 1719.33it/s]
# parsing log, completed traces ::  30%|▉  | 9476/31509 [00:07<00:12, 1713.77it/s]
# parsing log, completed traces ::  31%|▉  | 9650/31509 [00:07<00:12, 1720.68it/s]
# parsing log, completed traces ::  31%|▉  | 9823/31509 [00:07<00:12, 1687.53it/s]
# parsing log, completed traces ::  32%|▉  | 9992/31509 [00:07<00:12, 1662.09it/s]
# parsing log, completed traces ::  32%|▋ | 10159/31509 [00:07<00:12, 1643.58it/s]
# parsing log, completed traces ::  33%|▋ | 10324/31509 [00:08<00:13, 1621.53it/s]
# parsing log, completed traces ::  33%|▋ | 10487/31509 [00:08<00:13, 1613.36it/s]
# parsing log, completed traces ::  34%|▋ | 10649/31509 [00:08<00:12, 1610.19it/s]
# parsing log, completed traces ::  34%|▋ | 10811/31509 [00:08<00:13, 1568.27it/s]
# parsing log, completed traces ::  35%|▋ | 10969/31509 [00:08<00:13, 1555.56it/s]
# parsing log, completed traces ::  35%|▋ | 11139/31509 [00:08<00:12, 1596.77it/s]
# parsing log, completed traces ::  36%|▋ | 11308/31509 [00:08<00:12, 1623.12it/s]
# parsing log, completed traces ::  36%|▋ | 11471/31509 [00:08<00:12, 1606.25it/s]
# parsing log, completed traces ::  37%|▋ | 11637/31509 [00:08<00:12, 1621.23it/s]
# parsing log, completed traces ::  37%|▋ | 11812/31509 [00:09<00:11, 1656.07it/s]
# parsing log, completed traces ::  38%|▊ | 11984/31509 [00:09<00:11, 1673.61it/s]
# parsing log, completed traces ::  39%|▊ | 12157/31509 [00:09<00:11, 1688.28it/s]
# parsing log, completed traces ::  39%|▊ | 12326/31509 [00:09<00:11, 1678.02it/s]
# parsing log, completed traces ::  40%|█▏ | 12494/31509 [00:10<00:41, 458.21it/s]
# parsing log, completed traces ::  40%|█▏ | 12657/31509 [00:10<00:32, 579.76it/s]
# parsing log, completed traces ::  41%|█▏ | 12827/31509 [00:10<00:25, 724.32it/s]
# parsing log, completed traces ::  41%|█▏ | 12996/31509 [00:10<00:21, 874.68it/s]
# parsing log, completed traces ::  42%|▊ | 13173/31509 [00:10<00:17, 1037.05it/s]
# parsing log, completed traces ::  42%|▊ | 13347/31509 [00:10<00:15, 1180.82it/s]
# parsing log, completed traces ::  43%|▊ | 13513/31509 [00:10<00:13, 1287.32it/s]
# parsing log, completed traces ::  43%|▊ | 13679/31509 [00:11<00:12, 1378.35it/s]
# parsing log, completed traces ::  44%|▉ | 13847/31509 [00:11<00:12, 1455.43it/s]
# parsing log, completed traces ::  44%|▉ | 14013/31509 [00:11<00:11, 1484.46it/s]
# parsing log, completed traces ::  45%|▉ | 14181/31509 [00:11<00:11, 1537.53it/s]
# parsing log, completed traces ::  46%|▉ | 14347/31509 [00:11<00:10, 1571.67it/s]
# parsing log, completed traces ::  46%|▉ | 14512/31509 [00:11<00:10, 1587.51it/s]
# parsing log, completed traces ::  47%|▉ | 14677/31509 [00:11<00:10, 1551.46it/s]
# parsing log, completed traces ::  47%|▉ | 14837/31509 [00:11<00:10, 1562.88it/s]
# parsing log, completed traces ::  48%|▉ | 14998/31509 [00:11<00:10, 1575.87it/s]
# parsing log, completed traces ::  48%|▉ | 15181/31509 [00:11<00:09, 1649.91it/s]
# parsing log, completed traces ::  49%|▉ | 15353/31509 [00:12<00:09, 1669.55it/s]
# parsing log, completed traces ::  49%|▉ | 15531/31509 [00:12<00:09, 1701.15it/s]
# parsing log, completed traces ::  50%|▉ | 15708/31509 [00:12<00:09, 1720.69it/s]
# parsing log, completed traces ::  50%|█ | 15881/31509 [00:12<00:09, 1718.11it/s]
# parsing log, completed traces ::  51%|█ | 16055/31509 [00:12<00:08, 1723.05it/s]
# parsing log, completed traces ::  52%|█ | 16228/31509 [00:12<00:08, 1717.58it/s]
# parsing log, completed traces ::  52%|█ | 16400/31509 [00:12<00:08, 1714.14it/s]
# parsing log, completed traces ::  53%|█ | 16573/31509 [00:12<00:08, 1718.28it/s]
# parsing log, completed traces ::  53%|█ | 16745/31509 [00:12<00:08, 1715.49it/s]
# parsing log, completed traces ::  54%|█ | 16917/31509 [00:12<00:08, 1715.51it/s]
# parsing log, completed traces ::  54%|█ | 17095/31509 [00:13<00:08, 1733.13it/s]
# parsing log, completed traces ::  55%|█ | 17269/31509 [00:13<00:08, 1713.20it/s]
# parsing log, completed traces ::  55%|█ | 17441/31509 [00:13<00:08, 1714.56it/s]
# parsing log, completed traces ::  56%|█ | 17615/31509 [00:13<00:08, 1721.16it/s]
# parsing log, completed traces ::  56%|█▏| 17792/31509 [00:13<00:07, 1732.59it/s]
# parsing log, completed traces ::  57%|█▏| 17968/31509 [00:13<00:07, 1739.18it/s]
# parsing log, completed traces ::  58%|█▏| 18142/31509 [00:13<00:07, 1738.81it/s]
# parsing log, completed traces ::  58%|█▏| 18316/31509 [00:13<00:07, 1703.69it/s]
# parsing log, completed traces ::  59%|█▏| 18499/31509 [00:13<00:07, 1738.77it/s]
# parsing log, completed traces ::  59%|█▏| 18674/31509 [00:13<00:07, 1737.49it/s]
# parsing log, completed traces ::  60%|█▏| 18848/31509 [00:14<00:07, 1715.54it/s]
# parsing log, completed traces ::  60%|█▏| 19028/31509 [00:14<00:07, 1739.55it/s]
# parsing log, completed traces ::  61%|█▏| 19209/31509 [00:14<00:06, 1759.61it/s]
# parsing log, completed traces ::  62%|█▏| 19387/31509 [00:14<00:06, 1765.01it/s]
# parsing log, completed traces ::  62%|█▏| 19564/31509 [00:14<00:06, 1751.07it/s]
# parsing log, completed traces ::  63%|█▎| 19740/31509 [00:14<00:06, 1736.59it/s]
# parsing log, completed traces ::  63%|█▎| 19914/31509 [00:14<00:06, 1709.87it/s]
# parsing log, completed traces ::  64%|█▎| 20090/31509 [00:14<00:06, 1720.75it/s]
# parsing log, completed traces ::  64%|█▎| 20271/31509 [00:14<00:06, 1745.51it/s]
# parsing log, completed traces ::  65%|█▎| 20446/31509 [00:14<00:06, 1731.98it/s]
# parsing log, completed traces ::  65%|█▎| 20620/31509 [00:15<00:06, 1731.23it/s]
# parsing log, completed traces ::  66%|█▎| 20798/31509 [00:15<00:06, 1743.43it/s]
# parsing log, completed traces ::  67%|█▎| 20973/31509 [00:15<00:06, 1718.91it/s]
# parsing log, completed traces ::  67%|█▎| 21148/31509 [00:15<00:06, 1726.54it/s]
# parsing log, completed traces ::  68%|█▎| 21326/31509 [00:15<00:05, 1742.35it/s]
# parsing log, completed traces ::  68%|█▎| 21510/31509 [00:15<00:05, 1771.23it/s]
# parsing log, completed traces ::  69%|█▍| 21688/31509 [00:15<00:05, 1739.38it/s]
# parsing log, completed traces ::  69%|█▍| 21872/31509 [00:15<00:05, 1767.54it/s]
# parsing log, completed traces ::  70%|█▍| 22054/31509 [00:15<00:05, 1782.95it/s]
# parsing log, completed traces ::  71%|█▍| 22233/31509 [00:16<00:05, 1769.78it/s]
# parsing log, completed traces ::  71%|█▍| 22411/31509 [00:16<00:05, 1768.41it/s]
# parsing log, completed traces ::  72%|██▏| 22588/31509 [00:17<00:20, 427.25it/s]
# parsing log, completed traces ::  72%|██▏| 22766/31509 [00:17<00:15, 552.89it/s]
# parsing log, completed traces ::  73%|██▏| 22932/31509 [00:17<00:12, 682.58it/s]
# parsing log, completed traces ::  73%|██▏| 23106/31509 [00:17<00:10, 834.04it/s]
# parsing log, completed traces ::  74%|██▏| 23269/31509 [00:17<00:08, 968.98it/s]
# parsing log, completed traces ::  74%|█▍| 23442/31509 [00:17<00:07, 1117.42it/s]
# parsing log, completed traces ::  75%|█▍| 23625/31509 [00:17<00:06, 1272.33it/s]
# parsing log, completed traces ::  76%|█▌| 23804/31509 [00:17<00:05, 1394.18it/s]
# parsing log, completed traces ::  76%|█▌| 23976/31509 [00:18<00:05, 1475.76it/s]
# parsing log, completed traces ::  77%|█▌| 24148/31509 [00:18<00:04, 1520.48it/s]
# parsing log, completed traces ::  77%|█▌| 24324/31509 [00:18<00:04, 1585.24it/s]
# parsing log, completed traces ::  78%|█▌| 24496/31509 [00:18<00:04, 1622.22it/s]
# parsing log, completed traces ::  78%|█▌| 24676/31509 [00:18<00:04, 1670.84it/s]
# parsing log, completed traces ::  79%|█▌| 24850/31509 [00:18<00:03, 1675.88it/s]
# parsing log, completed traces ::  79%|█▌| 25030/31509 [00:18<00:03, 1707.59it/s]
# parsing log, completed traces ::  80%|█▌| 25205/31509 [00:18<00:03, 1708.68it/s]
# parsing log, completed traces ::  81%|█▌| 25379/31509 [00:18<00:03, 1704.86it/s]
# parsing log, completed traces ::  81%|█▌| 25557/31509 [00:18<00:03, 1726.55it/s]
# parsing log, completed traces ::  82%|█▋| 25731/31509 [00:19<00:03, 1716.88it/s]
# parsing log, completed traces ::  82%|█▋| 25904/31509 [00:19<00:03, 1707.87it/s]
# parsing log, completed traces ::  83%|█▋| 26077/31509 [00:19<00:03, 1711.91it/s]
# parsing log, completed traces ::  83%|█▋| 26249/31509 [00:19<00:03, 1701.30it/s]
# parsing log, completed traces ::  84%|█▋| 26428/31509 [00:19<00:02, 1727.20it/s]
# parsing log, completed traces ::  84%|█▋| 26601/31509 [00:19<00:02, 1711.53it/s]
# parsing log, completed traces ::  85%|█▋| 26773/31509 [00:19<00:02, 1701.26it/s]
# parsing log, completed traces ::  86%|█▋| 26945/31509 [00:19<00:02, 1703.16it/s]
# parsing log, completed traces ::  86%|█▋| 27116/31509 [00:19<00:02, 1697.33it/s]
# parsing log, completed traces ::  87%|█▋| 27293/31509 [00:19<00:02, 1718.10it/s]
# parsing log, completed traces ::  87%|█▋| 27465/31509 [00:20<00:02, 1718.57it/s]
# parsing log, completed traces ::  88%|█▊| 27637/31509 [00:20<00:02, 1715.66it/s]
# parsing log, completed traces ::  88%|█▊| 27809/31509 [00:20<00:02, 1706.19it/s]
# parsing log, completed traces ::  89%|█▊| 27980/31509 [00:20<00:02, 1699.85it/s]
# parsing log, completed traces ::  89%|█▊| 28151/31509 [00:20<00:01, 1686.28it/s]
# parsing log, completed traces ::  90%|█▊| 28320/31509 [00:20<00:01, 1682.91it/s]
# parsing log, completed traces ::  90%|█▊| 28492/31509 [00:20<00:01, 1693.74it/s]
# parsing log, completed traces ::  91%|█▊| 28670/31509 [00:20<00:01, 1717.27it/s]
# parsing log, completed traces ::  92%|█▊| 28842/31509 [00:20<00:01, 1657.40it/s]
# parsing log, completed traces ::  92%|█▊| 29014/31509 [00:21<00:01, 1675.04it/s]
# parsing log, completed traces ::  93%|█▊| 29182/31509 [00:21<00:01, 1669.32it/s]
# parsing log, completed traces ::  93%|█▊| 29353/31509 [00:21<00:01, 1681.20it/s]
# parsing log, completed traces ::  94%|█▊| 29522/31509 [00:21<00:01, 1660.91it/s]
# parsing log, completed traces ::  94%|█▉| 29702/31509 [00:21<00:01, 1700.90it/s]
# parsing log, completed traces ::  95%|█▉| 29873/31509 [00:21<00:00, 1701.59it/s]
# parsing log, completed traces ::  95%|█▉| 30049/31509 [00:21<00:00, 1696.38it/s]
# parsing log, completed traces ::  96%|█▉| 30227/31509 [00:21<00:00, 1719.37it/s]
# parsing log, completed traces ::  97%|█▉| 30409/31509 [00:21<00:00, 1747.48it/s]
# parsing log, completed traces ::  97%|█▉| 30590/31509 [00:21<00:00, 1764.50it/s]
# parsing log, completed traces ::  98%|█▉| 30767/31509 [00:22<00:00, 1757.55it/s]
# parsing log, completed traces ::  98%|█▉| 30946/31509 [00:22<00:00, 1762.21it/s]
# parsing log, completed traces ::  99%|█▉| 31128/31509 [00:22<00:00, 1775.59it/s]
# parsing log, completed traces ::  99%|█▉| 31306/31509 [00:22<00:00, 1741.10it/s]
# parsing log, completed traces :: 100%|██| 31509/31509 [00:22<00:00, 1403.10it/s]
# parsing log, completed traces :: 100%|██| 17549/17549 [00:06<00:00, 2568.69it/s]

# %% [markdown]
# # Distribution of End Activities

# %% [markdown]
# Distribution of end activities for event_log_full

# %%
end_activities_distribution = pm4py.get_end_activities(event_log_full)
end_activities_distribution
# Out:
# {'A_Pending': 12792,
#  'O_Refused': 3719,
#  'O_Cancelled': 14708,
#  'A_Cancelled': 161,
#  'A_Denied': 33,
#  'A_Incomplete': 29,
#  'A_Validating': 3,
#  'O_Sent (online only)': 12,
#  'O_Sent (mail and online)': 20,
#  'A_Complete': 30,
#  'O_Returned': 2}

# %% [markdown]
# Distribution of end activities for event_log_full

# %%
end_activities_distribution_A = pm4py.get_end_activities(event_log_A)
end_activities_distribution_A
# Out:
# {'A_Pending': 11804, 'A_Cancelled': 3382, 'A_Denied': 2363}

# %% [markdown]
# #### Visualisation of the Distribution for Application Outcomes

# %%
activities = list(end_activities_distribution_A.keys())
counts = [end_activities_distribution_A[activity] for activity in activities]

plt.figure(figsize=(10, 6))
plt.bar(activities, counts, color='skyblue')
plt.xlabel('End Events')
plt.ylabel('Count')
plt.title('Distribution of Traces by End Event')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# #### Visualisation of the Successful and Unsuccessful Application Distribution

# %% [markdown]
# Concentrating exclusively on application outcomes produces three main results, categorized as either successful or unsuccessful applications. Specifically, A_Pending is considered a successful outcome for the loan application, whereas A_Denied and A_Cancelled are classified as unsuccessful outcomes.

# %%
successful_counts = [end_activities_distribution_A.get('A_Pending', 0)]
unsuccessful_counts = [count for activity, count in end_activities_distribution_A.items() if activity != 'A_Pending']

fig, ax = plt.subplots(figsize=(10, 6))


ax.bar('Successful Applications', successful_counts, color='green', label='Successful Applications')


ax.bar('Unsuccessful Applications', sum(unsuccessful_counts), color='red', label='Unsuccessful Applications')

ax.set_xlabel('Application Outcome')
ax.set_ylabel('Count')
ax.set_title('Distribution of Traces by Application Outcome')
ax.legend()

plt.show()

# %% [markdown]
# # Insigths about traces

# %% [markdown]
# We aim to predict loan application outcomes based on events labeled O_ and A_. When forecasting results after sending offers to applicants ((O_Sent (online only) and O_Sent (mail and online)), we will examine the complete event log (event_log_full).

# %% [markdown]
# List of all start activities

# %%
pm4py.get_start_activities(event_log_full)
# Out:
# {'A_Create Application': 31509}

# %% [markdown]
# Number of distinct trace variants.

# %%
len(pm4py.get_variants_as_tuples(event_log_full))
# Out:
# 2630

# %% [markdown]
# Transform the log into a dataframe

# %%
df = pm4py.convert_to_dataframe(event_log_full)
df.head(5)
# Out:
#         Action                EventID  EventOrigin org:resource
# 0      Created  Application_652823628  Application       User_1  \
# 1  statechange   ApplState_1582051990  Application       User_1
# 2  statechange    ApplState_642383566  Application       User_1
# 3  statechange     ApplState_99568828  Application      User_52
# 4      Created        Offer_148581083        Offer      User_52
#
#            concept:name lifecycle:transition
# 0  A_Create Application             complete  \
# 1           A_Submitted             complete
# 2             A_Concept             complete
# 3            A_Accepted             complete
# 4        O_Create Offer             complete
#
#                      time:timestamp           case:LoanGoal
# 0  2016-01-01 10:51:15.304000+01:00  Existing loan takeover  \
# 1  2016-01-01 10:51:15.352000+01:00  Existing loan takeover
# 2  2016-01-01 10:52:36.413000+01:00  Existing loan takeover
# 3  2016-01-02 12:23:04.299000+01:00  Existing loan takeover
# 4  2016-01-02 12:29:03.994000+01:00  Existing loan takeover
#
#   case:ApplicationType  case:RequestedAmount      case:concept:name
# 0           New credit               20000.0  Application_652823628  \
# 1           New credit               20000.0  Application_652823628
# 2           New credit               20000.0  Application_652823628
# 3           New credit               20000.0  Application_652823628
# 4           New credit               20000.0  Application_652823628
#
#    OfferedAmount  CreditScore Selected  MonthlyCost Accepted  NumberOfTerms
# 0            NaN          NaN      NaN          NaN      NaN            NaN  \
# 1            NaN          NaN      NaN          NaN      NaN            NaN
# 2            NaN          NaN      NaN          NaN      NaN            NaN
# 3            NaN          NaN      NaN          NaN      NaN            NaN
# 4        20000.0        979.0     True       498.29     True           44.0
#
#    FirstWithdrawalAmount OfferID
# 0                    NaN     NaN
# 1                    NaN     NaN
# 2                    NaN     NaN
# 3                    NaN     NaN
# 4                20000.0     NaN

# %% [markdown]
# Print the first trace

# %%
from pm4py.objects.log.util.log import project_traces
def print_nth(log, index):
    print(str(project_traces(event_log_full)[index]))
    

print_nth(event_log_full, 0)
# Out:
# ['A_Create Application', 'A_Submitted', 'A_Concept', 'A_Accepted', 'O_Create Offer', 'O_Created', 'O_Sent (mail and online)', 'A_Complete', 'A_Validating', 'O_Returned', 'A_Incomplete', 'A_Validating', 'O_Accepted', 'A_Pending']

# %% [markdown]
# # Process Model Visualization

# %% [markdown]
# Visualisation of DFG for the event log

# %%
dfg, start_activities, end_activities = pm4py.discover_dfg(event_log_full)
pm4py.view_dfg(dfg, start_activities, end_activities)

# %% [markdown]
# Alpha miner - net (places and transactions)

# %%
net, initial_marking, final_marking = pm4py.discover_petri_net_alpha(event_log_full)
pm4py.view_petri_net(net)

# %% [markdown]
# Inductive miner

# %%
net, initial_marking, final_marking = pm4py.discover_petri_net_inductive(event_log_full)
tree = pm4py.discover_process_tree_inductive(event_log_full)
pm4py.view_process_tree(tree)

# %% [markdown]
# Heuristic miner

# %%
heu_net = pm4py.discover_heuristics_net(event_log_full, dependency_threshold=0.90)
pm4py.view_heuristics_net(heu_net)

# %% [markdown]
# # Data Preporcessing: traces

# %% [markdown]
# Check type and correct if needed

# %%
df.dtypes
# Out:
# Action                    object
# EventID                   object
# EventOrigin               object
# org:resource              object
# concept:name              object
# lifecycle:transition      object
# time:timestamp            object
# case:LoanGoal             object
# case:ApplicationType      object
# case:RequestedAmount     float64
# case:concept:name         object
# OfferedAmount            float64
# CreditScore              float64
# Selected                  object
# MonthlyCost              float64
# Accepted                  object
# NumberOfTerms            float64
# FirstWithdrawalAmount    float64
# OfferID                   object
# dtype: object

# %%
df['time:timestamp'] = pd.to_datetime(df['time:timestamp'], utc=True)
df['Year'] = df['time:timestamp'].dt.year
df['Month'] = df['time:timestamp'].dt.month

# %%
df.head(5)
# Out:
#         Action                EventID  EventOrigin org:resource
# 0      Created  Application_652823628  Application       User_1  \
# 1  statechange   ApplState_1582051990  Application       User_1
# 2  statechange    ApplState_642383566  Application       User_1
# 3  statechange     ApplState_99568828  Application      User_52
# 4      Created        Offer_148581083        Offer      User_52
#
#            concept:name lifecycle:transition                   time:timestamp
# 0  A_Create Application             complete 2016-01-01 09:51:15.304000+00:00  \
# 1           A_Submitted             complete 2016-01-01 09:51:15.352000+00:00
# 2             A_Concept             complete 2016-01-01 09:52:36.413000+00:00
# 3            A_Accepted             complete 2016-01-02 11:23:04.299000+00:00
# 4        O_Create Offer             complete 2016-01-02 11:29:03.994000+00:00
#
#             case:LoanGoal case:ApplicationType  case:RequestedAmount  ...
# 0  Existing loan takeover           New credit               20000.0  ...  \
# 1  Existing loan takeover           New credit               20000.0  ...
# 2  Existing loan takeover           New credit               20000.0  ...
# 3  Existing loan takeover           New credit               20000.0  ...
# 4  Existing loan takeover           New credit               20000.0  ...
#
#   OfferedAmount  CreditScore  Selected MonthlyCost  Accepted NumberOfTerms
# 0           NaN          NaN       NaN         NaN       NaN           NaN  \
# 1           NaN          NaN       NaN         NaN       NaN           NaN
# 2           NaN          NaN       NaN         NaN       NaN           NaN
# 3           NaN          NaN       NaN         NaN       NaN           NaN
# 4       20000.0        979.0      True      498.29      True          44.0
#
#    FirstWithdrawalAmount  OfferID  Year  Month
# 0                    NaN      NaN  2016      1
# 1                    NaN      NaN  2016      1
# 2                    NaN      NaN  2016      1
# 3                    NaN      NaN  2016      1
# 4                20000.0      NaN  2016      1
#
# [5 rows x 21 columns]

# %%
case_attr_df = df.groupby('case:concept:name').agg({
    'case:LoanGoal': 'first',
    'case:RequestedAmount': 'first',
    'case:ApplicationType': 'first',
    'Month': 'first',
    'Year': 'first'
}).reset_index()

# %%
case_attr_df.head(5)
# Out:
#         case:concept:name           case:LoanGoal  case:RequestedAmount
# 0  Application_1000086665  Other, see explanation                5000.0  \
# 1  Application_1000158214        Home improvement               12500.0
# 2  Application_1000311556                     Car               45000.0
# 3  Application_1000334415  Other, see explanation                5000.0
# 4  Application_1000339879  Existing loan takeover               37500.0
#
#   case:ApplicationType  Month  Year
# 0           New credit      8  2016
# 1           New credit      6  2016
# 2           New credit      4  2016
# 3           New credit      9  2016
# 4           New credit      3  2016

# %% [markdown]
# # Visualaization of the traces

# %% [markdown]
# Number of traces by year and month

# %%
fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot()


temp = case_attr_df.groupby(['Year', 'Month']).size().reset_index(name='Count')


temp['YearMonth'] = temp['Year'].astype(str) + '-' + temp['Month'].astype(str)

grid = sns.barplot(x='YearMonth', y='Count', data=temp, color='yellowgreen')

ax.set_xlabel("Years and Months")  
ax.set_ylabel("Number of Traces")  
plt.title('Number of Traces by Years and Months')
plt.xticks(rotation=45) 
plt.show()

# %% [markdown]
# Distribution of Cases by Application Type

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='case:ApplicationType', data=case_attr_df, palette='viridis', order=case_attr_df['case:ApplicationType'].value_counts().index)
plt.xlabel('Application Type')
plt.ylabel('Number of Cases')
plt.title('Distribution of Cases by Application Type')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Distribution of Cases by Loan Goal

# %%
plt.figure(figsize=(18, 8))
sns.countplot(x='case:LoanGoal', data=case_attr_df, palette='viridis', order=case_attr_df['case:LoanGoal'].value_counts().index)
plt.xlabel('Loan Goal')
plt.ylabel('Number of Cases')
plt.title('Distribution of Cases by Loan Goal')
plt.xticks(rotation=45)
plt.show()
